# %%
# !pip install diffusers transformers accelerate controlnet_aux torch safetensors gdown xformers

# %%
from diffusers import StableDiffusionControlNetPipeline, StableDiffusionPipeline, ControlNetModel
from controlnet_aux import CannyDetector
import torch
from PIL import Image
from controlnet_aux import CannyDetector
from google.colab import files

# %%
pipe=StableDiffusionPipeline.from_pretrained("nitrosocke/Ghibli-Diffusion",torch_dtype=torch.float16).to("cuda")
pipe.enable_attention_slicing()
pipe.enable_xformers_memory_efficient_attention()
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
prompt="""
  Transform this character into a Studio Ghibli-style anime portrait, smile, detailed, expressive eyes, soft cel-shading, painterly background, Miyazaki-inspired design, warm colors, gentle highlights, fantasy aesthetic, 4K detailed, Studio Ghibli style, Hayao Miyazaki aesthetic, soft watercolor textures, warm golden lighting, whimsical clouds, detailed foliage, peaceful atmosphere, cinematic composition, 4K detailed
  """
image=pipe(prompt).images[0]
display(image)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (85 > 77). Running this sequence through the model will result in indexing errors
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['atmosphere , cinematic composition , 4 k detailed']
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
